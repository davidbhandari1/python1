# %%
try:
    file=open('daves.csv','x')
    file.close()
except:
    print('file is already presnt')
# Out:
# file is already presnt

# %%
#to read excel file not csv file :
import pandas as pd 
df = pd.read_excel('Book1.xlsx')
df
# Out:
#      Ram  ktm
# 0  hari   pkr
# 1  shyam  btw

# %%
import csv
data = [['name','age','add'],
        ['Ram',45,'Kathmandu'],
       ['Shyam',34,'Bhaktapur'],
       ['Hari',34,'Lalitpur']]
file = open('daves.csv','w')
x=csv.writer(file)
x.writerows(data)
file.close()

# %%
import pandas as pd
df =pd.read_csv('daves.csv')
df
# Out:
#     name  age        add
# 0    Ram   45  Kathmandu
# 1  Shyam   34  Bhaktapur
# 2   Hari   34   Lalitpur

# %%
df = pd.read_csv('daves.csv',nrows=2)
df
# Out:
#     name  age        add
# 0    Ram   45  Kathmandu
# 1  Shyam   34  Bhaktapur

# %%
df=pd.read_csv('daves.csv',index_col='add')
df
# Out:
#             name  age
# add
# Kathmandu    Ram   45
# Bhaktapur  Shyam   34
# Lalitpur    Hari   34

# %%
df=pd.read_csv('daves.csv',index_col='add')
df.head(3)
# Out:
#             name  age
# add
# Kathmandu    Ram   45
# Bhaktapur  Shyam   34
# Lalitpur    Hari   34

# %%
df=pd.read_csv('daves.csv')
df.tail(2)
# Out:
#     name  age        add
# 1  Shyam   34  Bhaktapur
# 2   Hari   34   Lalitpur

# %%
df=pd.read_csv('daves.csv')
df.loc[1:3]
# Out:
#     name  age        add
# 1  Shyam   34  Bhaktapur
# 2   Hari   34   Lalitpur

# %%
df=pd.read_csv('daves.csv',index_col='add')
df.loc[df['age'] ==34]
# Out:
#             name  age
# add
# Bhaktapur  Shyam   34
# Lalitpur    Hari   34

# %%
df=pd.read_csv('daves.csv')
df[(df['age']==34) &(df['add']=='Lalitpur')]
# Out:
#    name  age       add
# 2  Hari   34  Lalitpur

# %%
import pandas as pd
# list inside dict
data = {'name':['Ram','Shyam','Hari','Sita','Gita'],
       'age':[23,45,67,89,43],
       'add':['Kathmandu','Bara','Jhapa','Bhaktapur','Lalitpur']}
df = pd.DataFrame(data)
df.to_csv('new_data.csv')
df
# Out:
#     name  age        add
# 0    Ram   23  Kathmandu
# 1  Shyam   45       Bara
# 2   Hari   67      Jhapa
# 3   Sita   89  Bhaktapur
# 4   Gita   43   Lalitpur

# %%
#Advance Pandas
import pandas as pd
df= pd.read_excel('india.xlsx')
df
# Out:
#                     States/UTs   Area  \
# 0                        India  Urban
# 1                        India  Rural
# 2                        India  Total
# 3    Andaman & Nicobar Islands  Urban
# 4    Andaman & Nicobar Islands  Rural
# ..                         ...    ...
# 106                Uttarakhand  Rural
# 107                Uttarakhand  Total
# 108                West Bengal  Urban
# 109                West Bengal  Rural
# 110                West Bengal  Total
#
#     Children age 5 years who attended pre-primary school during the school year 2019-20 (%)  \
# 0                                                18.06
# 1                                                11.98
# 2                                                13.62
# 3                                                    *
# 4                                                33.67
# ..                                                 ...
# 106                                              32.17
# ...

# %%
df.shape
# Out:
# (111, 7)

# %%
df.describe()
# Out:
#        Women (age 15-49) who are literate4 (%)  \
# count                               111.000000
# mean                                 79.858198
# std                                  17.462620
# min                                 -69.230000
# 25%                                  74.820000
# 50%                                  82.960000
# 75%                                  87.680000
# max                                  99.140000
#
#        Women (age 15-49)  with 10 or more years of schooling (%)
# count                                         111.000000
# mean                                           47.630270
# std                                            16.296502
# min                                           -30.770000
# 25%                                            35.440000
# 50%                                            49.060000
# 75%                                            59.820000
# max                                            79.780000

# %%
df.values
# Out:
# array([['India', 'Urban', 18.06, 83.01, 89.55, 56.28, 62.11],
#        ['India', 'Rural', 11.98, 65.9, 81.54, 33.7, 43.72],
#        ['India', 'Total', 13.62, 71.46, 84.37, 41.04, 50.21],
#        ['Andaman & Nicobar Islands', 'Urban', '*', 86.55, 89.27, 59.71,
#         59.41],
#        ['Andaman & Nicobar Islands', 'Rural', 33.67, 85.58, 94.65, 47.57,
#         47.65],
#        ['Andaman & Nicobar Islands', 'Total', 42.61, 85.97, 92.53, 52.47,
#         52.28],
#        ['Andhra Pradesh', 'Urban', 10.15, 79.01, 86.4, 51.2, 59.54],
#        ['Andhra Pradesh', 'Rural', 9.83, 63.84, 76.28, 34.28, 42.54],
#        ['Andhra Pradesh', 'Total', 9.92, 68.64, 79.48, 39.63, 47.91],
#        ['Arunachal Pradesh', 'Urban', 8.03, 84.65, 92.13, 55.39, 64.12],
#        ['Arunachal Pradesh', 'Rural', 5.54, 71.63, 85.6, 36.19, 44.97],
#        ['Arunachal Pradesh', 'Total', 5.9, 73.78, 86.69, 39.36, 48.18],
#        ['Assam', 'Urban', 4.13, 87.47, 92.62, 49.02, 53.24],
# ...

# %%
df.iloc[1:5]
# Out:
#                   States/UTs   Area  \
# 1                      India  Rural
# 2                      India  Total
# 3  Andaman & Nicobar Islands  Urban
# 4  Andaman & Nicobar Islands  Rural
#
#   Children age 5 years who attended pre-primary school during the school year 2019-20 (%)  \
# 1                                              11.98
# 2                                              13.62
# 3                                                  *
# 4                                              33.67
#
#    Women (age 15-49) who are literate4 (%)  \
# 1                                    65.90
# 2                                    71.46
# 3                                    86.55
# 4                                    85.58
#
#   Men (age 15-49) who are literate4 (%)  \
# 1                                 81.54
# 2                                 84.37
# 3                                 89.27
# 4                                 94.65
#
# ...

# %%
df.head()
# Out:
#                   States/UTs   Area  \
# 0                      India  Urban
# 1                      India  Rural
# 2                      India  Total
# 3  Andaman & Nicobar Islands  Urban
# 4  Andaman & Nicobar Islands  Rural
#
#   Children age 5 years who attended pre-primary school during the school year 2019-20 (%)  \
# 0                                              18.06
# 1                                              11.98
# 2                                              13.62
# 3                                                  *
# 4                                              33.67
#
#    Women (age 15-49) who are literate4 (%)  \
# 0                                    83.01
# 1                                    65.90
# 2                                    71.46
# 3                                    86.55
# 4                                    85.58
#
#   Men (age 15-49) who are literate4 (%)  \
# 0                                 89.55
# ...

# %%
df.iloc[15:25]
# Out:
#                                 States/UTs   Area  \
# 15                                   Bihar  Urban
# 16                                   Bihar  Rural
# 17                                   Bihar  Total
# 18                              Chandigarh  Urban
# 19                              Chandigarh  Rural
# 20                              Chandigarh  Total
# 21                            Chhattisgarh  Urban
# 22                            Chhattisgarh  Rural
# 23                            Chhattisgarh  Total
# 24  Dadra and Nagar Haveli & Daman and Diu  Urban
#
#    Children age 5 years who attended pre-primary school during the school year 2019-20 (%)  \
# 15                                              18.51
# 16                                              10.48
# 17                                              11.53
# 18                                                6.4
# 19                                                  *
# ...

# %%
df.iloc[23]
# Out:
# States/UTs                                                                                 Chhattisgarh
# Area                                                                                              Total
# Children age 5 years who attended pre-primary school during the school year 2019-20 (%)            4.62
# Women (age 15-49) who are literate4 (%)                                                           74.62
# Men (age 15-49) who are literate4 (%)                                                             87.26
# Women (age 15-49)  with 10 or more years of schooling (%)                                         36.89
# Men (age 15-49)  with 10 or more years of schooling (%)                                           41.45
# Name: 23, dtype: object

# %%
df.loc[df['Men (age 15-49) who are literate4 (%)']== 83.95]
# Out:
#    States/UTs   Area  \
# 15      Bihar  Urban
#
#    Children age 5 years who attended pre-primary school during the school year 2019-20 (%)  \
# 15                                              18.51
#
#     Women (age 15-49) who are literate4 (%)  \
# 15                                    74.93
#
#    Men (age 15-49) who are literate4 (%)  \
# 15                                 83.95
#
#     Women (age 15-49)  with 10 or more years of schooling (%)  \
# 15                                              47.99
#
#    Men (age 15-49)  with 10 or more years of schooling (%)
# 15                                              57.11

# %%
df.loc[(df['States/UTs']=='Bihar') & (df['Women (age 15-49) who are literate4 (%)'] ==74.93)]
# Out:
#    States/UTs   Area  \
# 15      Bihar  Urban
#
#    Children age 5 years who attended pre-primary school during the school year 2019-20 (%)  \
# 15                                              18.51
#
#     Women (age 15-49) who are literate4 (%)  \
# 15                                    74.93
#
#    Men (age 15-49) who are literate4 (%)  \
# 15                                 83.95
#
#     Women (age 15-49)  with 10 or more years of schooling (%)  \
# 15                                              47.99
#
#    Men (age 15-49)  with 10 or more years of schooling (%)
# 15                                              57.11

# %%
df.loc[(df['States/UTs']== 'Bihar')  & (df['Area']=='Urban')]
# Out:
#    States/UTs   Area  \
# 15      Bihar  Urban
#
#    Children age 5 years who attended pre-primary school during the school year 2019-20 (%)  \
# 15                                              18.51
#
#     Women (age 15-49) who are literate4 (%)  \
# 15                                    74.93
#
#    Men (age 15-49) who are literate4 (%)  \
# 15                                 83.95
#
#     Women (age 15-49)  with 10 or more years of schooling (%)  \
# 15                                              47.99
#
#    Men (age 15-49)  with 10 or more years of schooling (%)
# 15                                              57.11

# %%
df
# Out:
#                     States/UTs   Area  \
# 0                        India  Urban
# 1                        India  Rural
# 2                        India  Total
# 3    Andaman & Nicobar Islands  Urban
# 4    Andaman & Nicobar Islands  Rural
# ..                         ...    ...
# 106                Uttarakhand  Rural
# 107                Uttarakhand  Total
# 108                West Bengal  Urban
# 109                West Bengal  Rural
# 110                West Bengal  Total
#
#     Children age 5 years who attended pre-primary school during the school year 2019-20 (%)  \
# 0                                                18.06
# 1                                                11.98
# 2                                                13.62
# 3                                                    *
# 4                                                33.67
# ..                                                 ...
# 106                                              32.17
# ...

# %%
x=df.sort_values('States/UTs')
x
# Out:
#                     States/UTs   Area  \
# 3    Andaman & Nicobar Islands  Urban
# 4    Andaman & Nicobar Islands  Rural
# 5    Andaman & Nicobar Islands  Total
# 6               Andhra Pradesh  Urban
# 7               Andhra Pradesh  Rural
# ..                         ...    ...
# 105                Uttarakhand  Urban
# 107                Uttarakhand  Total
# 109                West Bengal  Rural
# 108                West Bengal  Urban
# 110                West Bengal  Total
#
#     Children age 5 years who attended pre-primary school during the school year 2019-20 (%)  \
# 3                                                    *
# 4                                                33.67
# 5                                                42.61
# 6                                                10.15
# 7                                                 9.83
# ..                                                 ...
# 105                                               35.8
# ...

# %%
20.13+81.62
# Out:
# 101.75

# %%
df.stat=df['Children age 5 years who attended pre-primary school during the school year 2019-20 (%)'] + df['Men (age 15-49) who are literate4 (%)']
df.stat
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     162     try:
# --> 163         result = func(left, right)
#     164     except TypeError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ...

# %%
df=df.drop(columns=['Children age 5 years who attended pre-primary school during the school year 2019-20 (%)'])
df
# Out:
#                     States/UTs   Area  \
# 0                        India  Urban
# 1                        India  Rural
# 2                        India  Total
# 3    Andaman & Nicobar Islands  Urban
# 4    Andaman & Nicobar Islands  Rural
# ..                         ...    ...
# 106                Uttarakhand  Rural
# 107                Uttarakhand  Total
# 108                West Bengal  Urban
# 109                West Bengal  Rural
# 110                West Bengal  Total
#
#      Women (age 15-49) who are literate4 (%)  \
# 0                                      83.01
# 1                                      65.90
# 2                                      71.46
# 3                                      86.55
# 4                                      85.58
# ..                                       ...
# 106                                    79.78
# 107                                    81.57
# 108                                    83.37
# ...

# %%
df
# Out:
#                     States/UTs   Area  \
# 0                        India  Urban
# 1                        India  Rural
# 2                        India  Total
# 3    Andaman & Nicobar Islands  Urban
# 4    Andaman & Nicobar Islands  Rural
# ..                         ...    ...
# 106                Uttarakhand  Rural
# 107                Uttarakhand  Total
# 108                West Bengal  Urban
# 109                West Bengal  Rural
# 110                West Bengal  Total
#
#      Women (age 15-49) who are literate4 (%)  \
# 0                                      83.01
# 1                                      65.90
# 2                                      71.46
# 3                                      86.55
# 4                                      85.58
# ..                                       ...
# 106                                    79.78
# 107                                    81.57
# 108                                    83.37
# ...

# %%
df.to_csv('modified.csv')

# %%
df=pd.read_csv('modified.csv')
df
# Out:
#      Unnamed: 0                 States/UTs   Area  \
# 0             0                      India  Urban
# 1             1                      India  Rural
# 2             2                      India  Total
# 3             3  Andaman & Nicobar Islands  Urban
# 4             4  Andaman & Nicobar Islands  Rural
# ..          ...                        ...    ...
# 106         106                Uttarakhand  Rural
# 107         107                Uttarakhand  Total
# 108         108                West Bengal  Urban
# 109         109                West Bengal  Rural
# 110         110                West Bengal  Total
#
#      Women (age 15-49) who are literate4 (%)  \
# 0                                      83.01
# 1                                      65.90
# 2                                      71.46
# 3                                      86.55
# 4                                      85.58
# ..                                       ...
# ...

# %%
# Group by function
df.groupby('Men (age 15-49) who are literate4 (%)').mean()
# Out:
#                                        Unnamed: 0  \
# Men (age 15-49) who are literate4 (%)
# *                                            19.0
# -93.47                                       76.0
# -96.32                                       55.0
# 100                                          54.0
# 76.28                                         7.0
# ...                                           ...
# 98.21                                        50.0
# 98.5                                         28.0
# 99.05                                        56.0
# 99.17                                        48.0
# 99.24                                        69.0
#
#                                        Women (age 15-49) who are literate4 (%)  \
# Men (age 15-49) who are literate4 (%)
# *                                                                       -69.23
# -93.47                                                                   89.02
# ...

# %%
df.groupby('Men (age 15-49) who are literate4 (%)').count()
# Out:
#                                        Unnamed: 0  States/UTs  Area  \
# Men (age 15-49) who are literate4 (%)
# *                                               1           1     1
# -93.47                                          1           1     1
# -96.32                                          1           1     1
# 100                                             1           1     1
# 76.28                                           1           1     1
# ...                                           ...         ...   ...
# 98.21                                           1           1     1
# 98.5                                            1           1     1
# 99.05                                           1           1     1
# 99.17                                           1           1     1
# 99.24                                           1           1     1
#
#                                        Women (age 15-49) who are literate4 (%)  \
# ...

# %%
for df in pd.read_csv('modified.csv',chunksize=5):
    print(df)
# Out:
#    Unnamed: 0                 States/UTs   Area  \
# 0           0                      India  Urban
# 1           1                      India  Rural
# 2           2                      India  Total
# 3           3  Andaman & Nicobar Islands  Urban
# 4           4  Andaman & Nicobar Islands  Rural
#
#    Women (age 15-49) who are literate4 (%)  \
# 0                                    83.01
# 1                                    65.90
# 2                                    71.46
# 3                                    86.55
# 4                                    85.58
#
#    Men (age 15-49) who are literate4 (%)  \
# 0                                  89.55
# 1                                  81.54
# 2                                  84.37
# 3                                  89.27
# 4                                  94.65
#
#    Women (age 15-49)  with 10 or more years of schooling (%)  \
# 0                                              56.28
# ...

# %%
for df in pd.read_csv('modified.csv',chunksize=5):
    print('CHUNK DF')
    print(df)
# Out:
# CHUNK DF
#    Unnamed: 0                 States/UTs   Area  \
# 0           0                      India  Urban
# 1           1                      India  Rural
# 2           2                      India  Total
# 3           3  Andaman & Nicobar Islands  Urban
# 4           4  Andaman & Nicobar Islands  Rural
#
#    Women (age 15-49) who are literate4 (%)  \
# 0                                    83.01
# 1                                    65.90
# 2                                    71.46
# 3                                    86.55
# 4                                    85.58
#
#    Men (age 15-49) who are literate4 (%)  \
# 0                                  89.55
# 1                                  81.54
# 2                                  84.37
# 3                                  89.27
# 4                                  94.65
#
#    Women (age 15-49)  with 10 or more years of schooling (%)  \
# 0                                              56.28
# ...
